# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(2, 2), facecolor='lightskyblue', layout='constrained')
fig.suptitle('Figure')
ax = fig.add_subplot()
ax.set_title('Axes', loc='left', fontstyle='oblique', fontsize='medium')
# Out:
# Text(0.0, 1.0, 'Axes')

# %% [markdown]
# **-** A backend for rendering matplotlib figures when code cell is executed:
#
# - %matplotlib inline   : creates static plots with default trim or expand to figure size
#
# - %matplotlib widget   : for interactive plots
#
# - %matplotlib notebook : for interactive plots

# %% [markdown]
# ### Creating Figures

# %%
fig, axs = plt.subplots(2, 2, figsize=(4, 3), layout='constrained')

# %%
fig, axs = plt.subplot_mosaic([['A', 'right'], ['B', 'right']],
                              figsize=(4, 3), layout='constrained')
for ax_name, ax in axs.items():
    ax.text(.5, .5, ax_name, ha='center', va='center')

# %%
fig = plt.figure(layout='constrained', facecolor='lightskyblue')
fig.suptitle('Figure')
figL, figR = fig.subfigures(1, 2)
figL.set_facecolor('thistle')
axL = figL.subplots(2, 1, sharex=True)
axL[1].set_xlabel('x [m]')
figL.suptitle('Left subfigure')
figR.set_facecolor('paleturquoise')
axR = figR.subplots(1, 2, sharey=True)
axR[0].set_title('Axes 1')
figR.suptitle('Right subfigure')
# Out:
# Text(0.5, 0.98, 'Right subfigure')

# %%
fig.savefig('MyFigure.png', dpi=200)
