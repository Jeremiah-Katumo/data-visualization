# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 8))
# for each axes, add an artist, in this case a simple plot at the middle of each axes
for i, ax in enumerate(axs.flat):
    x = np.linspace(0, 10, 100)
    y = np.sin(x + i)
    ax.plot(x, y)
    ax.set_title(f'Sine Wave {i+1}')
    ax.set_xlabel('X-axis')
    ax.set_ylabel('Y-axis')

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 8))
# for each axes, add an artist, in this case a simple plot at the middle of each axes
for row in range(2):
    for col in range(2):
        axs[row, col].plot([0.25, 0.75], [0.25, 0.75], color='blue')
        axs[row, col].set_title(f'Plot at ({row}, {col})')
        axs[row, col].set_xlabel('X-axis')
        axs[row, col].set_ylabel('Y-axis')
        
fig.suptitle('2x2 Subplots with Individual Plots', fontsize=16)
plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(3.5, 2.5), layout='constrained')
# for each axes, add an artist, in this case a simple plot at the middle of each axes
for row in range(2):
    for col in range(2):
        axs[row, col].annotate(f'axs[{row}, {col}]', xy=(.5, .5), xycoords='axes fraction',
                               transform=axs[row, col].transAxes, ha='center', va='center',
                               fontsize=16, color='darkgrey', alpha=0.5)
        
fig.suptitle('plt.subplots() returns a Figure and Axes array', fontsize=16)
# Out:
# Text(0.5, 0.98, 'plt.subplots() returns a Figure and Axes array')

# %%
fig, axs = plt.subplots(ncols=2, nrows=2, figsize=(3.5, 2.5),
                        layout="constrained")
# for each Axes, add an artist, in this case a nice label in the middle...
for row in range(2):
    for col in range(2):
        axs[row, col].annotate(f'axs[{row}, {col}]', (0.5, 0.5),
                            transform=axs[row, col].transAxes,
                            ha='center', va='center', fontsize=18,
                            color='darkgrey')
fig.suptitle('plt.subplots()')
# Out:
# Text(0.5, 0.98, 'plt.subplots()')

# %% [markdown]
# ### Axes labelling and annotation

# %%
fig, ax = plt.subplots(figsize=(5, 3), layout='constrained')
np.random.seed(19680801)
t = np.arange(200)
x = np.cumsum(np.random.randn(200))
y = np.cumsum(np.random.randn(200))
linesx = ax.plot(t, x, label='Random walk x')
linesy = ax.plot(t, y, label='Random walk y')

ax.set_xlabel('Time [s]')
ax.set_ylabel('Distance [km]')
ax.set_title('Random walk example')
ax.legend()

# %% [markdown]
# ### Axes limits, scales, and ticking

# %%
fig, ax = plt.subplots(figsize=(4, 2.5), layout='constrained')
np.random.seed(19680801)
t = np.arange(200)
x = 2**np.cumsum(np.random.randn(200))
linesx = ax.plot(t, x)
ax.set_yscale('log')
ax.set_xlim([20, 180])
# Out:
# (20.0, 180.0)

# %%
fig, ax = plt.subplots(figsize=(4, 2.5))
ax.plot(np.arange(10))
ax.tick_params(top=True, labeltop=True, color='red', axis='x',
               labelcolor='green')

# %% [markdown]
# ### Axes Layout

# %%
fig, axs = plt.subplots(ncols=2, figsize=(7, 2.5), layout='constrained')
np.random.seed(19680801)
t = np.arange(200)
x = np.cumsum(np.random.randn(200))
axs[0].plot(t, x)
axs[0].set_title('aspect="auto"')

axs[1].plot(t, x)
axs[1].set_aspect(3)
axs[1].set_title('aspect=3')
